# %%
import pandas as pd
import os
import ast

# %%
PATH_IN = '/Users/williamjallot/Desktop/ADA/Milestone1/data/MovieSummaries'

fname = os.path.join(PATH_IN, 'movie.metadata.tsv')
movie = pd.read_csv(fname, delimiter='\t', header=None)
movie.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie name', 'Movie release date', 'Movie box office revenue', 'Movie runtime', 'Movie languages (Freebase ID:name tuples)', 'Movie countries (Freebase ID:name tuples)', 'Movie genres (Freebase ID:name tuples)']

fname = os.path.join(PATH_IN, 'character.metadata.tsv')
character = pd.read_csv(fname, delimiter='\t', header=None)
character.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie release date', 'Character name', 'Actor date of birth', ' Actor gender', 'Actor height (in meters)', 'Actor ethnicity (Freebase ID)', 'Actor name',
                     'Actor age at movie release', 'Freebase character/actor map ID', 'Freebase character ID', 'Freebase actor ID']

fname = os.path.join(PATH_IN, 'plot_summaries.txt')
plot_summaries = pd.read_csv(fname, delimiter='\t', header=None)
plot_summaries.columns = ['Wikipedia movie ID', 'Summary']


fname = os.path.join(PATH_IN, 'tvtropes.clusters.txt')
tvtropes = pd.read_csv(fname, delimiter='\t', header=None, names = ['Trope','StringDict'])


df['Dictionnary'] = tvtropes['StringDict'].apply(ast.literal_eval)
df = pd.json_normalize(df['Dictionnary'])
tvtropes['Character Name'] = df['char']
tvtropes['Movie name'] = df['movie']
tvtropes['Freebase movie ID'] = df['id']
tvtropes['Actor name'] = df['actor']
tvtropes = tvtropes.drop(tvtropes.columns[1], axis=1)


fname = os.path.join(PATH_IN, 'name.clusters.txt')
name_clusters = pd.read_csv(fname, delimiter='\t', header=None, names = ['Character Name','ID'])

# %%
character
# Out:
#         Wikipedia movie ID Freebase movie ID Movie release date  \
# 0                   975900         /m/03vyhn         2001-08-24
# 1                   975900         /m/03vyhn         2001-08-24
# 2                   975900         /m/03vyhn         2001-08-24
# 3                   975900         /m/03vyhn         2001-08-24
# 4                   975900         /m/03vyhn         2001-08-24
# ...                    ...               ...                ...
# 450664              913762         /m/03pcrp         1992-05-21
# 450665              913762         /m/03pcrp         1992-05-21
# 450666            28308153        /m/0cp05t9               1957
# 450667            28308153        /m/0cp05t9               1957
# 450668            28308153        /m/0cp05t9               1957
#
#                     Character name Actor date of birth  Actor gender  \
# 0                         Akooshay          1958-08-26             F
# 1       Lieutenant Melanie Ballard          1974-08-15             F
# 2              Desolation Williams          1969-06-15             M
# 3               Sgt Jericho Butler          1967-09-12             M
# 4                  Bashira Kincaid          1977-09-25             F
# ...                            ...                 ...           ...
# 450664                      Elensh             1970-05             F
# 450665                      Hibiki          1965-04-12             M
# 450666                         NaN          1941-11-18             M
# 450667                         NaN                 NaN           NaN
# 450668                         NaN                 NaN           NaN
#
#         Actor height (in meters) Actor ethnicity (Freebase ID)  \
# 0                          1.620                           NaN
# 1                          1.780                    /m/044038p
# 2                          1.727                       /m/0x67
# 3                          1.750                           NaN
# 4                          1.650                           NaN
# ...                          ...                           ...
# 450664                       NaN                           NaN
# 450665                       NaN                           NaN
# 450666                     1.730                     /m/02w7gg
# 450667                       NaN                           NaN
# 450668                       NaN                           NaN
#
#                 Actor name  Actor age at movie release  \
# 0           Wanda De Jesus                        42.0
# 1       Natasha Henstridge                        27.0
# 2                 Ice Cube                        32.0
# 3            Jason Statham                        33.0
# 4              Clea DuVall                        23.0
# ...                    ...                         ...
# 450664  Dorothy Elias-Fahn                         NaN
# 450665       Jonathan Fahn                        27.0
# 450666      David Hemmings                        15.0
# 450667    Roberta Paterson                         NaN
# 450668         John Rogers                         NaN
#
#        Freebase character/actor map ID Freebase character ID Freebase actor ID
# 0                           /m/0bgchxw            /m/0bgcj3x        /m/03wcfv7
# 1                            /m/0jys3m            /m/0bgchn4         /m/0346l4
# 2                            /m/0jys3g            /m/0bgchn_        /m/01vw26l
# 3                           /m/02vchl6            /m/0bgchnq         /m/034hyc
# 4                           /m/02vbb3r            /m/0bgchp9         /m/01y9xg
# ...                                ...                   ...               ...
# 450664                      /m/0kr406c            /m/0kr406h         /m/0b_vcv
# 450665                      /m/0kr405_            /m/0kr4090         /m/0bx7_j
# 450666                      /m/0g8ngmc                   NaN         /m/022g44
# 450667                      /m/0g8ngmj                   NaN        /m/0g8ngmm
# 450668                      /m/0g8ngmw                   NaN        /m/0btz19d
#
# [450669 rows x 13 columns]

# %%
movie
# Out:
#        Wikipedia movie ID Freebase movie ID  \
# 0                  975900         /m/03vyhn
# 1                 3196793         /m/08yl5d
# 2                28463795        /m/0crgdbh
# 3                 9363483        /m/0285_cd
# 4                  261236         /m/01mrr1
# ...                   ...               ...
# 81736            35228177        /m/0j7hxnt
# 81737            34980460        /m/0g4pl34
# 81738             9971909        /m/02pygw1
# 81739              913762         /m/03pcrp
# 81740            12476867        /m/02w7zz8
#
#                                               Movie name Movie release date  \
# 0                                         Ghosts of Mars         2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...         2000-02-16
# 2                                            Brun bitter               1988
# 3                                       White Of The Eye               1987
# 4                                      A Woman in Flames               1983
# ...                                                  ...                ...
# 81736                           Mermaids: The Body Found         2011-03-19
# 81737                                            Knuckle         2011-01-21
# 81738                                  Another Nice Mess         1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...         1992-05-21
# 81740                                            Spliced               2002
#
#        Movie box office revenue  Movie runtime  \
# 0                    14010832.0           98.0
# 1                           NaN           95.0
# 2                           NaN           83.0
# 3                           NaN          110.0
# 4                           NaN          106.0
# ...                         ...            ...
# 81736                       NaN          120.0
# 81737                       NaN           96.0
# 81738                       NaN           66.0
# 81739                       NaN          150.0
# 81740                       NaN           86.0
#
#       Movie languages (Freebase ID:name tuples)  \
# 0            {"/m/02h40lc": "English Language"}
# 1            {"/m/02h40lc": "English Language"}
# 2            {"/m/05f_3": "Norwegian Language"}
# 3            {"/m/02h40lc": "English Language"}
# 4             {"/m/04306rv": "German Language"}
# ...                                         ...
# 81736        {"/m/02h40lc": "English Language"}
# 81737        {"/m/02h40lc": "English Language"}
# 81738        {"/m/02h40lc": "English Language"}
# 81739         {"/m/03_9r": "Japanese Language"}
# 81740        {"/m/02h40lc": "English Language"}
#
#                Movie countries (Freebase ID:name tuples)  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                   Movie genres (Freebase ID:name tuples)
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                                {"/m/07s9rl0": "Drama"}
# ...                                                  ...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 9 columns]

# %%
movie['Movie name'].value_counts()[movie['Movie name'].value_counts() >= 2]
# Out:
# Movie name
# Alice in Wonderland      17
# Macbeth                  16
# Les Misérables           13
# A Christmas Carol        13
# Hero                     12
#                          ..
# Perfect Day               2
# Straw Dogs                2
# Falling in Love Again     2
# Aradhana                  2
# Double Vision             2
# Name: count, Length: 4387, dtype: int64

# %%
movie[movie['Movie name'] == 'Alice in Wonderland']
# Out:
#        Wikipedia movie ID Freebase movie ID           Movie name  \
# 4113              2828945         /m/085bgh  Alice in Wonderland
# 5852                62180          /m/0gtkg  Alice in Wonderland
# 9719             14482638        /m/04jpg2p  Alice in Wonderland
# 10537             9522001        /m/02phpvf  Alice in Wonderland
# 17101            13895620        /m/03cmhm1  Alice in Wonderland
# 18184            22966826        /m/063_py3  Alice in Wonderland
# 28939              912670         /m/03p86z  Alice in Wonderland
# 41969             2212695         /m/06wbq4  Alice in Wonderland
# 47640            28948624        /m/0dgqblh  Alice in Wonderland
# 51402             2828905         /m/085bd1  Alice in Wonderland
# 51805            16487646        /m/03y8gmq  Alice in Wonderland
# 53085            23669602        /m/06zr25h  Alice in Wonderland
# 56441              769066         /m/039zft  Alice in Wonderland
# 59085            25588092        /m/09rvr2z  Alice in Wonderland
# 72432            10544615        /m/02qhd5h  Alice in Wonderland
# 73970            13758649        /m/03chc1w  Alice in Wonderland
# 74267              212265         /m/01f39b  Alice in Wonderland
#
#       Movie release date  Movie box office revenue  Movie runtime  \
# 4113             1903-05                       NaN           10.0
# 5852          1933-12-22                       NaN           76.0
# 9719          2010-03-05              1.024300e+09          108.0
# 10537               2006                       NaN            NaN
# 17101                NaN                       NaN            NaN
# 18184               1950                       NaN           83.0
# 28939               1966                       NaN           72.0
# 41969         1976-12-10              9.000000e+07           81.0
# 47640               1983                       NaN           90.0
# 51402         1999-02-28                       NaN          150.0
# 51805               1988                       NaN           51.0
# 53085         1915-01-19                       NaN           52.0
# 56441         1951-07-26                       NaN           75.0
# 59085         1931-09-30                       NaN           58.0
# 72432                NaN                       NaN            NaN
# 73970                NaN                       NaN           46.0
# 74267         1985-12-09                       NaN          192.0
#
#       Movie languages (Freebase ID:name tuples)  \
# 4113                                         {}
# 5852         {"/m/02h40lc": "English Language"}
# 9719         {"/m/02h40lc": "English Language"}
# 10537        {"/m/0999q": "Malayalam Language"}
# 17101                                        {}
# 18184                                        {}
# 28939        {"/m/02h40lc": "English Language"}
# 41969        {"/m/02h40lc": "English Language"}
# 47640        {"/m/02h40lc": "English Language"}
# 51402        {"/m/02h40lc": "English Language"}
# 51805        {"/m/02h40lc": "English Language"}
# 53085        {"/m/02h40lc": "English Language"}
# 56441        {"/m/02h40lc": "English Language"}
# 59085                                        {}
# 72432                                        {}
# 73970        {"/m/02h40lc": "English Language"}
# 74267        {"/m/02h40lc": "English Language"}
#
#                Movie countries (Freebase ID:name tuples)  \
# 4113                      {"/m/07ssc": "United Kingdom"}
# 5852           {"/m/09c7w0": "United States of America"}
# 9719   {"/m/09c7w0": "United States of America", "/m/...
# 10537                              {"/m/03rk0": "India"}
# 17101          {"/m/09c7w0": "United States of America"}
# 18184          {"/m/09c7w0": "United States of America"}
# 28939                     {"/m/07ssc": "United Kingdom"}
# 41969          {"/m/09c7w0": "United States of America"}
# 47640                                                 {}
# 51402  {"/m/09c7w0": "United States of America", "/m/...
# 51805                         {"/m/0chghy": "Australia"}
# 53085          {"/m/09c7w0": "United States of America"}
# 56441          {"/m/09c7w0": "United States of America"}
# 59085          {"/m/09c7w0": "United States of America"}
# 72432          {"/m/09c7w0": "United States of America"}
# 73970  {"/m/09c7w0": "United States of America", "/m/...
# 74267          {"/m/09c7w0": "United States of America"}
#
#                   Movie genres (Freebase ID:name tuples)
# 4113   {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 5852   {"/m/01hmnh": "Fantasy", "/m/01g6gs": "Black-a...
# 9719   {"/m/01zhp": "Computer Animation", "/m/0hqxf":...
# 10537  {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...
# 17101  {"/m/04rlf": "Music", "/m/0hqxf": "Family Film...
# 18184  {"/m/07s9rl0": "Drama", "/m/0hqxf": "Family Fi...
# 28939  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 41969  {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 47640  {"/m/0hqxf": "Family Film", "/m/03k9fj": "Adve...
# 51402  {"/m/03k9fj": "Adventure", "/m/015w9s": "Telev...
# 51805  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 53085  {"/m/06ppq": "Silent film", "/m/01g6gs": "Blac...
# 56441  {"/m/03k9fj": "Adventure", "/m/04xvh5": "Costu...
# 59085                           {"/m/01hmnh": "Fantasy"}
# 72432                                                 {}
# 73970  {"/m/0gw5n2f": "Japanese Movies", "/m/01hmnh":...
# 74267  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...

# %%
movie['Movie release date'].unique()
# Out:
# array(['2001-08-24', '2000-02-16', '1988', ..., '1927-11-22',
#        '1972-09-22', '1992-05-21'], dtype=object)

# %%
plot_summaries
# Out:
#        Wikipedia movie ID                                            Summary
# 0                23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1                31186339  The nation of Panem consists of a wealthy Capi...
# 2                20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3                 2231378  The Lemon Drop Kid , a New York City swindler,...
# 4                  595909  Seventh-day Adventist Church pastor Michael Ch...
# ...                   ...                                                ...
# 42298            34808485  The story is about Reema , a young Muslim scho...
# 42299             1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42300            35102018  American Luthier focuses on Randy Parsons’ tra...
# 42301             8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42302             6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42303 rows x 2 columns]

# %%
tvtropes
# Out:
#                        Trope                     Character Name  \
# 0    absent_minded_professor          Professor Philip Brainard
# 1    absent_minded_professor                 Professor Keenbean
# 2    absent_minded_professor                 Dr. Reinhardt Lane
# 3    absent_minded_professor                 Dr. Harold Medford
# 4    absent_minded_professor                     Daniel Jackson
# ..                       ...                                ...
# 496                young_gun                        Morgan Earp
# 497                young_gun                      Colorado Ryan
# 498                young_gun                         Tom Sawyer
# 499                young_gun  William H. 'Billy the Kid' Bonney
# 500                young_gun                               Jake
#
#                                 Movie name Freebase movie ID       Actor name
# 0                                  Flubber         /m/0jy9q0   Robin Williams
# 1                              Richie Rich        /m/02vchl3  Michael McShane
# 2                               The Shadow         /m/0k6fkc     Ian McKellen
# 3                                    Them!         /m/0k6_br     Edmund Gwenn
# 4                                 Stargate         /m/0k3rhh     James Spader
# ..                                     ...               ...              ...
# 496                              Tombstone         /m/0k776f      Bill Paxton
# 497                              Rio Bravo         /m/0k2kqg     Ricky Nelson
# 498  The League of Extraordinary Gentlemen         /m/0k5nsh       Shane West
# 499                          Young Guns II        /m/03lrjk0   Emilio Estevez
# 500                              Silverado         /m/0k39jj    Kevin Costner
#
# [501 rows x 5 columns]

# %% [markdown]
# Will we see Alice in the wonderlands use ninchakus ? Genre evolutoon, stereotypes characters, f

# %% [markdown]
# Do the film follow the main immigration in the country ? Italian migration in USA -> more italian film
