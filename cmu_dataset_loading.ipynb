# %%
import pandas as pd
import os
import ast
import wikipediaapi

# %%
PATH_IN = '/Users/williamjallot/Desktop/ADA/Milestone1/data/MovieSummaries'

fname = os.path.join(PATH_IN, 'movie.metadata.tsv')
movie = pd.read_csv(fname, delimiter='\t', header=None)
movie.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie name', 'Movie release date', 'Movie box office revenue', 'Movie runtime', 'Movie languages (Freebase ID:name tuples)', 'Movie countries (Freebase ID:name tuples)', 'Movie genres (Freebase ID:name tuples)']

fname = os.path.join(PATH_IN, 'character.metadata.tsv')
character = pd.read_csv(fname, delimiter='\t', header=None)
character.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie release date', 'Character name', 'Actor date of birth', ' Actor gender', 'Actor height (in meters)', 'Actor ethnicity (Freebase ID)', 'Actor name',
                     'Actor age at movie release', 'Freebase character/actor map ID', 'Freebase character ID', 'Freebase actor ID']

fname = os.path.join(PATH_IN, 'plot_summaries.txt')
plot_summaries = pd.read_csv(fname, delimiter='\t', header=None)
plot_summaries.columns = ['Wikipedia movie ID', 'Summary']


fname = os.path.join(PATH_IN, 'tvtropes.clusters.txt')
tvtropes = pd.read_csv(fname, delimiter='\t', header=None, names = ['Trope','StringDict'])


tvtropes['Dictionnary'] = tvtropes['StringDict'].apply(ast.literal_eval)
tvtropes = pd.json_normalize(tvtropes['Dictionnary'])
tvtropes['Character Name'] = tvtropes['char']
tvtropes['Movie name'] = tvtropes['movie']
tvtropes['Freebase movie ID'] = tvtropes['id']
tvtropes['Actor name'] = tvtropes['actor']
tvtropes = tvtropes.drop(tvtropes.columns[1], axis=1)


fname = os.path.join(PATH_IN, 'name.clusters.txt')
name_clusters = pd.read_csv(fname, delimiter='\t', header=None, names = ['Character Name','ID'])

# %%
character[character['Actor name'] == 'Will Smith']
# Out:
#         Wikipedia movie ID Freebase movie ID Movie release date  \
# 19194              2162986         /m/06rhz7         2006-12-15
# 24952              8452805        /m/0273yvf         2000-10-27
# 30303              1037237         /m/040fg_         2003-07-09
# 46316               334874         /m/01xbxn         2004-09-10
# 71084               673599         /m/031t2d         2002-07-03
# 95176               167599         /m/016dj8         1997-07-01
# 109419             5587045         /m/0dtxp9               1999
# 122678              684771         /m/032sl_         1998-11-16
# 148940            34429259        /m/0hhgh70         2013-06-07
# 194292            18698236        /m/04y5j64         1993-12-08
# 221871            20926377        /m/02vrgnr         2008-07-02
# 238463             1524596         /m/057yjg         2005-02-10
# 241289              673613         /m/031t49         1995-04-07
# 255989             6641931         /m/0gfsq9         2007-12-12
# 257802             3412440         /m/09b4h7               1993
# 258873             1525408         /m/057__d         2000-10-29
# 261443              244610         /m/01kff7         1999-06-30
# 284602            13049327        /m/0661m4p         2012-05-14
# 295245              171626         /m/01719t         2001-12-25
# 358089            15762321        /m/03nsm5x         2008-12-19
# 364217              950274         /m/03spmc         2002-06-28
# 379387            11470600        /m/02rd_56         1992-09-11
# 412600              568780         /m/02qzh2         2004-03-26
# 420521              564947         /m/02qkwl         2004-07-15
# 440837               52389          /m/0ds2n         1996-06-25
#
#                              Character name Actor date of birth  Actor gender  \
# 19194                   Christopher Gardner          1968-09-25             M
# 24952                                   NaN          1968-09-25             M
# 30303                 Detective Mike Lowrey          1968-09-25             M
# 46316                                 Oscar          1968-09-25             M
# 71084                             Agent Jay          1968-09-25             M
# 95176                             Agent Jay          1968-09-25             M
# 109419                                  NaN          1968-09-25             M
# 122678                  Robert Clayton Dean          1968-09-25             M
# 148940                         Cypher Raige          1968-09-25             M
# 194292                                 Paul          1968-09-25             M
# 221871                              Hancock          1968-09-25             M
# 238463                Alex "Hitch" Hitchens          1968-09-25             M
# 241289                Detective Mike Lowrey          1968-09-25             M
# 255989                   Dr. Robert Neville          1968-09-25             M
# 257802                     Tea Cake Walters          1968-09-25             M
# 258873                         Bagger Vance          1968-09-25             M
# 261443                        James T. West          1968-09-25             M
# 284602                              Agent J          1968-09-25             M
# 295245                         Muhammad Ali          1968-09-25             M
# 358089                           Tim Thomas          1968-09-25             M
# 364217                                  NaN          1968-09-25             M
# 379387                                Manny          1968-09-25             M
# 412600                                  NaN          1968-09-25             M
# 420521                Detective Del Spooner          1968-09-25             M
# 440837  Captain Steven "Steve" Hiller, USMC          1968-09-25             M
#
#         Actor height (in meters) Actor ethnicity (Freebase ID)  Actor name  \
# 19194                       1.88                       /m/0x67  Will Smith
# 24952                       1.88                       /m/0x67  Will Smith
# 30303                       1.88                       /m/0x67  Will Smith
# 46316                       1.88                       /m/0x67  Will Smith
# 71084                       1.88                       /m/0x67  Will Smith
# 95176                       1.88                       /m/0x67  Will Smith
# 109419                      1.88                       /m/0x67  Will Smith
# 122678                      1.88                       /m/0x67  Will Smith
# 148940                      1.88                       /m/0x67  Will Smith
# 194292                      1.88                       /m/0x67  Will Smith
# 221871                      1.88                       /m/0x67  Will Smith
# 238463                      1.88                       /m/0x67  Will Smith
# 241289                      1.88                       /m/0x67  Will Smith
# 255989                      1.88                       /m/0x67  Will Smith
# 257802                      1.88                       /m/0x67  Will Smith
# 258873                      1.88                       /m/0x67  Will Smith
# 261443                      1.88                       /m/0x67  Will Smith
# 284602                      1.88                       /m/0x67  Will Smith
# 295245                      1.88                       /m/0x67  Will Smith
# 358089                      1.88                       /m/0x67  Will Smith
# 364217                      1.88                       /m/0x67  Will Smith
# 379387                      1.88                       /m/0x67  Will Smith
# 412600                      1.88                       /m/0x67  Will Smith
# 420521                      1.88                       /m/0x67  Will Smith
# 440837                      1.88                       /m/0x67  Will Smith
#
#         Actor age at movie release Freebase character/actor map ID  \
# 19194                         38.0                      /m/02h7tjp
# 24952                         32.0                      /m/0cgc817
# 30303                         34.0                       /m/0jtymk
# 46316                         35.0                       /m/0k35dm
# 71084                         33.0                       /m/0k0ln2
# 95176                         28.0                       /m/0k0llm
# 109419                        30.0                      /m/03lmx7q
# 122678                        30.0                       /m/0jxw5l
# 148940                        44.0                      /m/0hm8n24
# 194292                        25.0                      /m/052fl2t
# 221871                        39.0                      /m/03btsr6
# 238463                        36.0                       /m/0jzggr
# 241289                        26.0                       /m/0jtyl6
# 255989                        39.0                      /m/02tb9z_
# 257802                        24.0                       /m/0k09w4
# 258873                        32.0                       /m/0k5ny1
# 261443                        30.0                       /m/0k82t9
# 284602                        43.0                      /m/0667gq2
# 295245                        33.0                       /m/0jt6vz
# 358089                        40.0                      /m/0bnp4hx
# 364217                        33.0                      /m/0ggd695
# 379387                        23.0                      /m/01xrqkw
# 412600                        35.0                      /m/04m1gz5
# 420521                        35.0                       /m/0jzrgx
# 440837                        27.0                       /m/0jzx3_
#
#        Freebase character ID Freebase actor ID
# 19194             /m/02nwq7y         /m/0147dk
# 24952                    NaN         /m/0147dk
# 30303             /m/04j6bsp         /m/0147dk
# 46316             /m/04j6bvq         /m/0147dk
# 71084              /m/0fnv5w         /m/0147dk
# 95176              /m/0fnv5w         /m/0147dk
# 109419                   NaN         /m/0147dk
# 122678            /m/04j6bt5         /m/0147dk
# 148940            /m/0k6_x8k         /m/0147dk
# 194292            /m/0bq36f3         /m/0147dk
# 221871            /m/09vqrcz         /m/0147dk
# 238463            /m/04j6btq         /m/0147dk
# 241289            /m/04j6bsp         /m/0147dk
# 255989            /m/04j6bth         /m/0147dk
# 257802            /m/04j6bv6         /m/0147dk
# 258873            /m/04j6bsx         /m/0147dk
# 261443            /m/0hn2v_c         /m/0147dk
# 284602            /m/02nwj4j         /m/0147dk
# 295245            /m/02nw80c         /m/0147dk
# 358089            /m/0j2t2sd         /m/0147dk
# 364217                   NaN         /m/0147dk
# 379387            /m/02nwn1n         /m/0147dk
# 412600                   NaN         /m/0147dk
# 420521            /m/04j6bvf         /m/0147dk
# 440837            /m/04j6bvy         /m/0147dk

# %%
movie
# Out:
#        Wikipedia movie ID Freebase movie ID  \
# 0                  975900         /m/03vyhn
# 1                 3196793         /m/08yl5d
# 2                28463795        /m/0crgdbh
# 3                 9363483        /m/0285_cd
# 4                  261236         /m/01mrr1
# ...                   ...               ...
# 81736            35228177        /m/0j7hxnt
# 81737            34980460        /m/0g4pl34
# 81738             9971909        /m/02pygw1
# 81739              913762         /m/03pcrp
# 81740            12476867        /m/02w7zz8
#
#                                               Movie name Movie release date  \
# 0                                         Ghosts of Mars         2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...         2000-02-16
# 2                                            Brun bitter               1988
# 3                                       White Of The Eye               1987
# 4                                      A Woman in Flames               1983
# ...                                                  ...                ...
# 81736                           Mermaids: The Body Found         2011-03-19
# 81737                                            Knuckle         2011-01-21
# 81738                                  Another Nice Mess         1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...         1992-05-21
# 81740                                            Spliced               2002
#
#        Movie box office revenue  Movie runtime  \
# 0                    14010832.0           98.0
# 1                           NaN           95.0
# 2                           NaN           83.0
# 3                           NaN          110.0
# 4                           NaN          106.0
# ...                         ...            ...
# 81736                       NaN          120.0
# 81737                       NaN           96.0
# 81738                       NaN           66.0
# 81739                       NaN          150.0
# 81740                       NaN           86.0
#
#       Movie languages (Freebase ID:name tuples)  \
# 0            {"/m/02h40lc": "English Language"}
# 1            {"/m/02h40lc": "English Language"}
# 2            {"/m/05f_3": "Norwegian Language"}
# 3            {"/m/02h40lc": "English Language"}
# 4             {"/m/04306rv": "German Language"}
# ...                                         ...
# 81736        {"/m/02h40lc": "English Language"}
# 81737        {"/m/02h40lc": "English Language"}
# 81738        {"/m/02h40lc": "English Language"}
# 81739         {"/m/03_9r": "Japanese Language"}
# 81740        {"/m/02h40lc": "English Language"}
#
#                Movie countries (Freebase ID:name tuples)  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                   Movie genres (Freebase ID:name tuples)
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                                {"/m/07s9rl0": "Drama"}
# ...                                                  ...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 9 columns]

# %%
movie['Movie name'].value_counts()[movie['Movie name'].value_counts() >= 2]
# Out:
# Movie name
# Alice in Wonderland      17
# Macbeth                  16
# Les Misérables           13
# A Christmas Carol        13
# Hero                     12
#                          ..
# Perfect Day               2
# Straw Dogs                2
# Falling in Love Again     2
# Aradhana                  2
# Double Vision             2
# Name: count, Length: 4387, dtype: int64

# %%
movie[movie['Movie name'] == 'Alice in Wonderland']
# Out:
#        Wikipedia movie ID Freebase movie ID           Movie name  \
# 4113              2828945         /m/085bgh  Alice in Wonderland
# 5852                62180          /m/0gtkg  Alice in Wonderland
# 9719             14482638        /m/04jpg2p  Alice in Wonderland
# 10537             9522001        /m/02phpvf  Alice in Wonderland
# 17101            13895620        /m/03cmhm1  Alice in Wonderland
# 18184            22966826        /m/063_py3  Alice in Wonderland
# 28939              912670         /m/03p86z  Alice in Wonderland
# 41969             2212695         /m/06wbq4  Alice in Wonderland
# 47640            28948624        /m/0dgqblh  Alice in Wonderland
# 51402             2828905         /m/085bd1  Alice in Wonderland
# 51805            16487646        /m/03y8gmq  Alice in Wonderland
# 53085            23669602        /m/06zr25h  Alice in Wonderland
# 56441              769066         /m/039zft  Alice in Wonderland
# 59085            25588092        /m/09rvr2z  Alice in Wonderland
# 72432            10544615        /m/02qhd5h  Alice in Wonderland
# 73970            13758649        /m/03chc1w  Alice in Wonderland
# 74267              212265         /m/01f39b  Alice in Wonderland
#
#       Movie release date  Movie box office revenue  Movie runtime  \
# 4113             1903-05                       NaN           10.0
# 5852          1933-12-22                       NaN           76.0
# 9719          2010-03-05              1.024300e+09          108.0
# 10537               2006                       NaN            NaN
# 17101                NaN                       NaN            NaN
# 18184               1950                       NaN           83.0
# 28939               1966                       NaN           72.0
# 41969         1976-12-10              9.000000e+07           81.0
# 47640               1983                       NaN           90.0
# 51402         1999-02-28                       NaN          150.0
# 51805               1988                       NaN           51.0
# 53085         1915-01-19                       NaN           52.0
# 56441         1951-07-26                       NaN           75.0
# 59085         1931-09-30                       NaN           58.0
# 72432                NaN                       NaN            NaN
# 73970                NaN                       NaN           46.0
# 74267         1985-12-09                       NaN          192.0
#
#       Movie languages (Freebase ID:name tuples)  \
# 4113                                         {}
# 5852         {"/m/02h40lc": "English Language"}
# 9719         {"/m/02h40lc": "English Language"}
# 10537        {"/m/0999q": "Malayalam Language"}
# 17101                                        {}
# 18184                                        {}
# 28939        {"/m/02h40lc": "English Language"}
# 41969        {"/m/02h40lc": "English Language"}
# 47640        {"/m/02h40lc": "English Language"}
# 51402        {"/m/02h40lc": "English Language"}
# 51805        {"/m/02h40lc": "English Language"}
# 53085        {"/m/02h40lc": "English Language"}
# 56441        {"/m/02h40lc": "English Language"}
# 59085                                        {}
# 72432                                        {}
# 73970        {"/m/02h40lc": "English Language"}
# 74267        {"/m/02h40lc": "English Language"}
#
#                Movie countries (Freebase ID:name tuples)  \
# 4113                      {"/m/07ssc": "United Kingdom"}
# 5852           {"/m/09c7w0": "United States of America"}
# 9719   {"/m/09c7w0": "United States of America", "/m/...
# 10537                              {"/m/03rk0": "India"}
# 17101          {"/m/09c7w0": "United States of America"}
# 18184          {"/m/09c7w0": "United States of America"}
# 28939                     {"/m/07ssc": "United Kingdom"}
# 41969          {"/m/09c7w0": "United States of America"}
# 47640                                                 {}
# 51402  {"/m/09c7w0": "United States of America", "/m/...
# 51805                         {"/m/0chghy": "Australia"}
# 53085          {"/m/09c7w0": "United States of America"}
# 56441          {"/m/09c7w0": "United States of America"}
# 59085          {"/m/09c7w0": "United States of America"}
# 72432          {"/m/09c7w0": "United States of America"}
# 73970  {"/m/09c7w0": "United States of America", "/m/...
# 74267          {"/m/09c7w0": "United States of America"}
#
#                   Movie genres (Freebase ID:name tuples)
# 4113   {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 5852   {"/m/01hmnh": "Fantasy", "/m/01g6gs": "Black-a...
# 9719   {"/m/01zhp": "Computer Animation", "/m/0hqxf":...
# 10537  {"/m/02l7c8": "Romance Film", "/m/07s9rl0": "D...
# 17101  {"/m/04rlf": "Music", "/m/0hqxf": "Family Film...
# 18184  {"/m/07s9rl0": "Drama", "/m/0hqxf": "Family Fi...
# 28939  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 41969  {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 47640  {"/m/0hqxf": "Family Film", "/m/03k9fj": "Adve...
# 51402  {"/m/03k9fj": "Adventure", "/m/015w9s": "Telev...
# 51805  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 53085  {"/m/06ppq": "Silent film", "/m/01g6gs": "Blac...
# 56441  {"/m/03k9fj": "Adventure", "/m/04xvh5": "Costu...
# 59085                           {"/m/01hmnh": "Fantasy"}
# 72432                                                 {}
# 73970  {"/m/0gw5n2f": "Japanese Movies", "/m/01hmnh":...
# 74267  {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...

# %%
movie['Movie release date'].unique()
# Out:
# array(['2001-08-24', '2000-02-16', '1988', ..., '1927-11-22',
#        '1972-09-22', '1992-05-21'], dtype=object)

# %%
plot_summaries
# Out:
#        Wikipedia movie ID                                            Summary
# 0                23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1                31186339  The nation of Panem consists of a wealthy Capi...
# 2                20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3                 2231378  The Lemon Drop Kid , a New York City swindler,...
# 4                  595909  Seventh-day Adventist Church pastor Michael Ch...
# ...                   ...                                                ...
# 42298            34808485  The story is about Reema , a young Muslim scho...
# 42299             1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42300            35102018  American Luthier focuses on Randy Parsons’ tra...
# 42301             8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42302             6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42303 rows x 2 columns]

# %%
tvtropes
# Out:
#                        Trope                     Character Name  \
# 0    absent_minded_professor          Professor Philip Brainard
# 1    absent_minded_professor                 Professor Keenbean
# 2    absent_minded_professor                 Dr. Reinhardt Lane
# 3    absent_minded_professor                 Dr. Harold Medford
# 4    absent_minded_professor                     Daniel Jackson
# ..                       ...                                ...
# 496                young_gun                        Morgan Earp
# 497                young_gun                      Colorado Ryan
# 498                young_gun                         Tom Sawyer
# 499                young_gun  William H. 'Billy the Kid' Bonney
# 500                young_gun                               Jake
#
#                                 Movie name Freebase movie ID       Actor name
# 0                                  Flubber         /m/0jy9q0   Robin Williams
# 1                              Richie Rich        /m/02vchl3  Michael McShane
# 2                               The Shadow         /m/0k6fkc     Ian McKellen
# 3                                    Them!         /m/0k6_br     Edmund Gwenn
# 4                                 Stargate         /m/0k3rhh     James Spader
# ..                                     ...               ...              ...
# 496                              Tombstone         /m/0k776f      Bill Paxton
# 497                              Rio Bravo         /m/0k2kqg     Ricky Nelson
# 498  The League of Extraordinary Gentlemen         /m/0k5nsh       Shane West
# 499                          Young Guns II        /m/03lrjk0   Emilio Estevez
# 500                              Silverado         /m/0k39jj    Kevin Costner
#
# [501 rows x 5 columns]

# %% [markdown]
# Will we see Alice in the wonderlands use ninchakus ? Genre evolutoon, stereotypes characters, f

# %% [markdown]
# Do the film follow the main immigration in the country ? Italian migration in USA -> more italian film

# %%
import requests

# Your API key
api_key = 'e82016a2'

# Base URL
base_url = 'http://www.omdbapi.com/'

# Example movie title
movie_title = ''

# Construct the full API endpoint URL
url = f"{base_url}?t={movie_title}&apikey={api_key}"

# Make the request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    if "Ratings" in data : 
         print(f"Ratings: {data['Ratings']}")
    if 'Awards' in data:
        awards_summary = data['Awards']
        print(f"Awards Summary: {awards_summary}")

        # Parse the awards field
        if 'Oscar' in awards_summary:
            oscar_info = awards_summary.split('Oscars')[0].strip()
            print(f"Oscars: {oscar_info}")
        
        if 'win' in awards_summary:
            win_info = awards_summary.split('Another ')[-1].split(' win')[0].strip()
            print(f"Other Wins: {win_info} wins")

        if 'nomination' in awards_summary:
            nom_info = awards_summary.split('&')[-1].split(' nomination')[0].strip()
            print(f"Nominations: {nom_info} nominations")

    else:
        print("Awards information not found.")
else:
    print(f"Error: {response.status_code}")
# Out:
# Awards information not found.

# %%
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('ADA (william.jallot@epfl.ch)', 'en', extract_format=wikipediaapi.ExtractFormat.WIKI)

page_py = wiki_wiki.page('Academy Award for Best Cinematography')

# %%
print(page_py.text)
# Out:
# The Academy Award for Best Cinematography is an Academy Award awarded each year to a cinematographer for work on one particular motion picture.
#
# History
# In its first film season, 1927–28, this award (like others such as the acting awards) was not tied to a specific film; all of the work by the nominated cinematographers during the qualifying period was listed after their names. The problem with this system became obvious the first year, since Karl Struss and Charles Rosher were nominated for their work together on Sunrise. Still, three other films shot individually by either Rosher or Struss were also listed as part of the nomination. In the second year, 1929, there were no nominations at all, although the Academy has a list of unofficial titles that were under consideration by the Board of Judges. In the third year, 1930, films, not cinematographers, were nominated, and the final award did not show the cinematographer's name.
# Finally, for the 1931 awards, the modern system in which individuals are nominated for a single film was adopted in all profession-related categories. From 1939 to 1966 with the exception of 1957, there were also separate awards for color and black-and-white cinematography. After Who's Afraid of Virginia Woolf? (1966), the most recent black-and-white films to win since then are Schindler's List (1993), Roma (2018) and Mank (2020).
# Floyd Crosby won the award for Tabu in 1931, which was the last silent film to win in this category. Hal Mohr won the only write-in Academy Award ever, in 1935 for A Midsummer Night's Dream. Mohr was also the first person to win for both black-and-white and color cinematography.
# No winners are lost, although some of the earliest nominees (and of the unofficial nominees of 1928–29) are lost, including The Devil Dancer (1927), The Magic Flame (1927), and 4 Devils (1928). The Right to Love (1930) is incomplete, and Sadie Thompson (1927) is incomplete and partially reconstructed with stills.
# David Lean holds the record for the director with the most films that won the Academy Award for Best Cinematography at the Oscars with five wins out of six nominations for Great Expectations, The Bridge on the River Kwai, Lawrence of Arabia, Doctor Zhivago, and Ryan's Daughter.
# The first nominees shot primarily on digital video were The Curious Case of Benjamin Button and Slumdog Millionaire in 2009, with Slumdog Millionaire being the first winner. The following year, Avatar was the first nominee and winner to be shot entirely on digital video.
# In 2018, Rachel Morrison became the first woman to receive a nomination. Prior to that, it had been the last non-acting Academy Award category to never nominate a woman.
# In January 2017, Bradford Young became the first African-American cinematographer to be nominated for an Academy Award, for his work on Arrival.
# In 2019, Alfonso Cuarón became the first winner of this category to have also served as director on the film, for Roma. This followed a public dispute between Cuarón and the Academy over the Academy's plan to shorten the Oscars broadcast by relegating four awards, including cinematography, to the commercial breaks in the show. Cuarón objected by saying, "In the history of cinema, masterpieces have existed without sound, without color, without a story, without actors and without music. No single film has ever existed without cinematography ..."
#
# Superlatives
# Winners and nominees
# Winners are listed first in colored row, followed by the other nominees.
#
# 1920s
# 1930s
# 1940s
# 1950s
# 1960s
# 1970s
# 1980s
# 1990s
# 2000s
# 2010s
# 2020s
# Multiple awards and nominations
# See also
# BAFTA Award for Best Cinematography
# Independent Spirit Award for Best Cinematography
# Critics' Choice Movie Award for Best Cinematography
# American Society of Cinematographers Award for Outstanding Achievement in Cinematography in Theatrical Releases
# Satellite Award for Best Cinematography
# List of Academy Award–nominated films
#
# Notes
# References
# External links
# Academy of Motion Picture Arts and Sciences official site
# The Official Academy Awards Database, listing all past nominees and winners

# %%
import re

# Sample text about Titanic, focusing only on the relevant part for brevity


# Define a regex pattern to match awards information
awards_pattern = re.compile(r"won.*?(?:Academy Awards?|Golden Globes?).*?including.*?(\w+.*?)(?:\.|$)", re.IGNORECASE)

# Find all matches of the pattern in the text
matches = re.findall(awards_pattern, page_py.text)

# Extract and print the awards
for match in matches:
    print(f"Awards: {match.strip()}")

# Alternatively, extract detailed awards won
academy_awards_pattern = re.compile(r"won.*?(\d+).*?(Academy Awards?|Oscars?)", re.IGNORECASE)
academy_matches = re.findall(academy_awards_pattern, page_py.text)

# Print detailed Academy Award count
for number, award in academy_matches:
    print(f"Titanic won {number} {award}.")
# Out:
# Titanic won 11 Academy Awards.
# Titanic won 70 Academy Awards.
# Titanic won 1933 Academy Awards.
# Titanic won 1997 Academy Award.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


driver = webdriver.Chrome()  


url = "https://en.wikipedia.org/wiki/Academy_Award_for_Best_Cinematography"
driver.get(url)


time.sleep(5)


tr_tags = driver.find_elements(By.TAG_NAME, 'tr')

for tr_tag in tr_tags:
    style = tr_tag.get_attribute('style')
    
    
    if 'rgb(250, 235, 134)' in style:  
      
        td_tags = tr_tag.find_elements(By.TAG_NAME, 'td')
        
  
        if len(td_tags) > 1:
            name = td_tags[0].text.strip()
            movie_info = td_tags[1].text.strip()
            print(f"Film: {name}, Director: {movie_info}")


driver.quit()
# Out:
# Film: Sunrise: A Song of Two Humans, Director: Charles Rosher
# Karl Struss
# Film: White Shadows in the South Seas, Director: Clyde De Vinna
# Film: With Byrd at the South Pole, Director: Joseph T. Rucker and Willard Van der Veer
# Film: Tabu: A Story of the South Seas, Director: Floyd Crosby
# Film: Shanghai Express, Director: Lee Garmes
# Film: A Farewell to Arms, Director: Charles Lang
# Film: Cleopatra, Director: Victor Milner
# Film: A Midsummer Night's Dream, Director: Hal Mohr [note 2]
# Film: Anthony Adverse, Director: Tony Gaudio
# Film: The Garden of Allah, Director: W. Howard Greene and Harold Rosson
# Film: The Good Earth, Director: Karl Freund
# Film: A Star Is Born, Director: W. Howard Greene
# Film: The Great Waltz, Director: Joseph Ruttenberg
# Film: Sweethearts, Director: Oliver T. Marsh and Allen Davey
# Film: Wuthering Heights, Director: Gregg Toland
# Film: Gone with the Wind, Director: Ernest Haller and Ray Rennahan
# Film: Rebecca, Director: George Barnes
# Film: The Thief of Bagdad, Director: Georges Périnal
# Film: How Green Was My Valley, Director: Arthur C. Miller
# Film: Blood and Sand, Director: Ernest Palmer and Ray Rennahan
# Film: Mrs. Miniver, Director: Joseph Ruttenberg
# Film: The Black Swan, Director: Leon Shamroy
# Film: The Song of Bernadette, Director: Arthur C. Miller
# Film: Phantom of the Opera, Director: Hal Mohr and W. Howard Greene
# Film: Laura, Director: Joseph LaShelle
# Film: Wilson, Director: Leon Shamroy
# Film: The Picture of Dorian Gray, Director: Harry Stradling
# Film: Leave Her to Heaven, Director: Leon Shamroy
# Film: Anna and the King of Siam, Director: Arthur C. Miller
# Film: The Yearling, Director: Charles Rosher, Leonard Smith and Arthur Arling
# Film: Great Expectations, Director: Guy Green
# Film: Black Narcissus, Director: Jack Cardiff
# Film: The Naked City, Director: William Daniels
# Film: Joan of Arc, Director: Joseph Valentine, William V. Skall and Winton C. Hoch
# Film: Battleground, Director: Paul C. Vogel
# Film: She Wore a Yellow Ribbon, Director: Winton C. Hoch
# Film: The Third Man, Director: Robert Krasker
# Film: King Solomon's Mines, Director: Robert Surtees
# Film: A Place in the Sun, Director: William C. Mellor
# Film: An American in Paris, Director: Alfred Gilks and John Alton
# Film: The Bad and the Beautiful, Director: Robert Surtees
# Film: The Quiet Man, Director: Winton C. Hoch and Archie Stout
# Film: From Here to Eternity, Director: Burnett Guffey
# Film: Shane, Director: Loyal Griggs
# Film: On the Waterfront, Director: Boris Kaufman
# Film: Three Coins in the Fountain, Director: Milton Krasner
# Film: The Rose Tattoo, Director: James Wong Howe
# Film: To Catch a Thief, Director: Robert Burks
# Film: Somebody Up There Likes Me, Director: Joseph Ruttenberg
# Film: Around the World in 80 Days, Director: Lionel Lindon
# Film: The Bridge on the River Kwai, Director: Jack Hildyard
# Film: The Defiant Ones, Director: Sam Leavitt
# Film: Gigi, Director: Joseph Ruttenberg
# Film: The Diary of Anne Frank, Director: William C. Mellor
# Film: Ben-Hur, Director: Robert Surtees
# Film: Sons and Lovers, Director: Freddie Francis
# Film: Spartacus, Director: Russell Metty
# Film: The Hustler, Director: Eugen Schüfftan
# Film: West Side Story, Director: Daniel L. Fapp
# Film: The Longest Day, Director: Jean Bourgoin and Walter Wottitz
# Film: Lawrence of Arabia, Director: Freddie Young
# Film: Hud, Director: James Wong Howe
# Film: Cleopatra, Director: Leon Shamroy
# Film: Zorba the Greek, Director: Walter Lassally
# Film: My Fair Lady, Director: Harry Stradling
# Film: Ship of Fools, Director: Ernest Laszlo
# Film: Doctor Zhivago, Director: Freddie Young
# Film: Who's Afraid of Virginia Woolf?, Director: Haskell Wexler
# Film: A Man for All Seasons, Director: Ted Moore
# Film: Bonnie and Clyde, Director: Burnett Guffey
# Film: Romeo and Juliet, Director: Pasqualino De Santis
# Film: Butch Cassidy and the Sundance Kid, Director: Conrad L. Hall
# Film: Ryan's Daughter, Director: Freddie Young
# Film: Fiddler on the Roof, Director: Oswald Morris
# Film: Cabaret, Director: Geoffrey Unsworth
# Film: Cries and Whispers, Director: Sven Nykvist
# Film: The Towering Inferno, Director: Fred J. Koenekamp and Joseph Biroc
# Film: Barry Lyndon, Director: John Alcott
# Film: Bound for Glory, Director: Haskell Wexler
# Film: Close Encounters of the Third Kind, Director: Vilmos Zsigmond
# Film: Days of Heaven, Director: Néstor Almendros
# Film: Apocalypse Now, Director: Vittorio Storaro
# Film: Tess, Director: Geoffrey Unsworth (posthumously) and Ghislain Cloquet
# Film: Reds, Director: Vittorio Storaro
# Film: Gandhi, Director: Billy Williams and Ronnie Taylor
# Film: Fanny and Alexander, Director: Sven Nykvist
# Film: The Killing Fields, Director: Chris Menges
# Film: Out of Africa, Director: David Watkin
# Film: The Mission, Director: Chris Menges
# Film: The Last Emperor, Director: Vittorio Storaro
# Film: Mississippi Burning, Director: Peter Biziou
# Film: Glory, Director: Freddie Francis
# Film: Dances with Wolves, Director: Dean Semler
# Film: JFK, Director: Robert Richardson
# Film: A River Runs Through It, Director: Philippe Rousselot
# Film: Schindler's List, Director: Janusz Kamiński
# Film: Legends of the Fall, Director: John Toll
# Film: Braveheart, Director: John Toll
# Film: The English Patient, Director: John Seale
# Film: Titanic, Director: Russell Carpenter
# Film: Saving Private Ryan, Director: Janusz Kamiński
# Film: American Beauty, Director: Conrad L. Hall
# Film: Crouching Tiger, Hidden Dragon, Director: Peter Pau
# Film: The Lord of the Rings: The Fellowship of the Ring, Director: Andrew Lesnie
# Film: Road to Perdition, Director: Conrad L. Hall (posthumously)
# Film: Master and Commander: The Far Side of the World, Director: Russell Boyd
# Film: The Aviator, Director: Robert Richardson
# Film: Memoirs of a Geisha, Director: Dion Beebe
# Film: Pan's Labyrinth, Director: Guillermo Navarro
# Film: There Will Be Blood, Director: Robert Elswit
# Film: Slumdog Millionaire, Director: Anthony Dod Mantle
# Film: Avatar, Director: Mauro Fiore
# Film: Inception, Director: Wally Pfister
# Film: Hugo, Director: Robert Richardson
# Film: Life of Pi, Director: Claudio Miranda
# Film: Gravity, Director: Emmanuel Lubezki
# Film: Birdman or (The Unexpected Virtue of Ignorance), Director: Emmanuel Lubezki
# Film: The Revenant, Director: Emmanuel Lubezki
# Film: La La Land, Director: Linus Sandgren
# Film: Roma, Director: Alfonso Cuarón
# Film: 1917, Director: Roger Deakins
# Film: Mank, Director: Erik Messerschmidt
# Film: Dune, Director: Greig Fraser
# Film: All Quiet on the Western Front, Director: James Friend
# Film: Oppenheimer, Director: Hoyte van Hoytema

# %%
# Set up the WebDriver
driver = webdriver.Chrome()  # Make sure to have ChromeDriver installed

# Specify the target URL
url = "https://en.wikipedia.org/wiki/Academy_Award_for_Best_Actor"
driver.get(url)

# Adding a wait to ensure all content is loaded
time.sleep(5)

# Find all 'tr' tags in the table to extract year, movie, and symbol information
tr_tags = driver.find_elements(By.TAG_NAME, 'tr')

# Iterate over each 'tr' tag to find the required information
for tr_tag in tr_tags:
    # Extract 'td' elements from the row
    td_tags = tr_tag.find_elements(By.TAG_NAME, 'td')

    if len(td_tags) > 0:
        # Extract the text content and background color from each 'td' tag
        for td_tag in td_tags:
            text = td_tag.text.strip()
            style = td_tag.get_attribute('style')

            # Check for specific symbols in the text and categorize them
            if '‡' in text:
                print(f"Winner: {text}")
            elif '§' in text:
                print(f"Winner Who Refused Award: {text}")
            elif '†' in text:
                print(f"Posthumous Winner or Nominee: {text}")

# Close the browser
driver.quit()
# Out:
# Winner: Emil Jannings ‡[A]
# Winner: Warner Baxter ‡
# Winner: George Arliss ‡[C]
# Winner: Lionel Barrymore ‡
# Winner: Wallace Beery ‡ (Tie) [D]
# Winner: Fredric March ‡ (Tie) [D]
# Winner: Charles Laughton ‡
# Winner: Clark Gable ‡
# Winner: Victor McLaglen ‡
# Winner: Paul Muni ‡
# Winner: Spencer Tracy ‡
# Winner: Spencer Tracy ‡
# Winner: Robert Donat ‡
# Winner: James Stewart ‡
# Winner: Gary Cooper ‡
# Winner: James Cagney ‡
# Winner: Paul Lukas ‡
# Winner: Bing Crosby ‡
# Winner: Ray Milland ‡
# Winner: Fredric March ‡
# Winner: Ronald Colman ‡
# Winner: Laurence Olivier ‡
# Winner: Broderick Crawford ‡
# Winner: José Ferrer ‡
# Winner: Humphrey Bogart ‡
# Winner: Gary Cooper ‡
# Winner: William Holden ‡
# Winner: Marlon Brando ‡
# Winner: Ernest Borgnine ‡
# Posthumous Winner or Nominee: James Dean †
# Winner: Yul Brynner ‡
# Posthumous Winner or Nominee: James Dean †
# Winner: Alec Guinness ‡
# Winner: David Niven ‡
# Winner: Charlton Heston ‡
# Winner: Burt Lancaster ‡
# Winner: Maximilian Schell ‡
# Winner: Gregory Peck ‡
# Winner: Sidney Poitier ‡
# Winner: Rex Harrison ‡
# Winner: Lee Marvin ‡
# Winner: Paul Scofield ‡
# Winner: Rod Steiger ‡
# Posthumous Winner or Nominee: Spencer Tracy †
# Winner: Cliff Robertson ‡
# Winner: John Wayne ‡
# Winner Who Refused Award: George C. Scott §[50]
# Winner: Gene Hackman ‡
# Winner Who Refused Award: Marlon Brando §[50]
# Winner: Jack Lemmon ‡
# Winner: Art Carney ‡
# Winner: Jack Nicholson ‡
# Posthumous Winner or Nominee: Peter Finch †
# Winner: Richard Dreyfuss ‡
# Winner: Jon Voight ‡
# Winner: Dustin Hoffman ‡
# Winner: Robert De Niro ‡
# Winner: Henry Fonda ‡
# Winner: Ben Kingsley ‡
# Winner: Robert Duvall ‡
# Winner: F. Murray Abraham ‡
# Winner: William Hurt ‡
# Winner: Paul Newman ‡
# Winner: Michael Douglas ‡
# Winner: Dustin Hoffman ‡
# Winner: Daniel Day-Lewis ‡
# Winner: Jeremy Irons ‡
# Winner: Anthony Hopkins ‡
# Winner: Al Pacino ‡
# Winner: Tom Hanks ‡
# Winner: Tom Hanks ‡
# Winner: Nicolas Cage ‡
# Posthumous Winner or Nominee: Massimo Troisi †
# Winner: Geoffrey Rush ‡
# Winner: Jack Nicholson ‡
# Winner: Roberto Benigni ‡
# Winner: Kevin Spacey ‡
# Winner: Russell Crowe ‡
# Winner: Denzel Washington ‡
# Winner: Adrien Brody ‡
# Winner: Sean Penn ‡
# Winner: Jamie Foxx ‡
# Winner: Philip Seymour Hoffman ‡
# Winner: Forest Whitaker ‡
# Winner: Daniel Day-Lewis ‡
# Winner: Sean Penn ‡
# Winner: Jeff Bridges ‡
# Winner: Colin Firth ‡
# Winner: Jean Dujardin ‡
# Winner: Daniel Day-Lewis ‡
# Winner: Matthew McConaughey ‡
# Winner: Eddie Redmayne ‡
# Winner: Leonardo DiCaprio ‡
# Winner: Casey Affleck ‡
# Winner: Gary Oldman ‡
# Winner: Rami Malek ‡
# Winner: Joaquin Phoenix ‡
# Winner: Anthony Hopkins ‡
# Posthumous Winner or Nominee: Chadwick Boseman †
# Winner: Will Smith ‡
# Winner: Brendan Fraser ‡
# Winner: Cillian Murphy ‡

# %%
# Out:
# 'https://www.mediawiki.org/'
